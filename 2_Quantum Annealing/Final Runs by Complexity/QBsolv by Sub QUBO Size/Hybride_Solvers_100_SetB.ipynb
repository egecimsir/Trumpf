# %% [markdown]
# ## Hybride Solvers : DWave's Leap and QBsolve+Dwave

# %%
import sys
sys.path.append("..")
from qubo_util import *
import wikipedia
import numpy as np
import pandas as pd
from prettytable import PrettyTable


import dimod
import numpy as np
import pandas as pd
import dwave.inspector
import matplotlib.pyplot as plt
from dwave.system.samplers import DWaveSampler
from dwave.embedding.chain_strength import scaled, uniform_torque_compensation
from dwave.system import DWaveSampler, FixedEmbeddingComposite, EmbeddingComposite

# %%
from dwave.cloud import Client
client = Client.from_config(config_file='/Users/jonas/Library/Application Support/dwave/dwave.conf')

# %% [markdown]
# ## Jobs Info

# %%
### Lets define the basics

bend = [0, 1, 2]
weld = [3, 4]
paint =  [5]

bend_length = 2
weld_length = 3
paint_length = 6

t_step = 3
t_step_in_sec = 30

# %%
jobs = jobs100 = [(0, 0, 4, 3, 6, 9),
 (1, 0, 2, 6, 0, 4)]

operations = job_info(jobs100, bend_length, weld_length, paint_length, t_step_in_sec, bend, weld, paint, t_step)
# Out:
# The maximal maketime for the given operations is: 1980 second(s).
# Which is equal to: 66 time steps.
#
#
# Anzahl an Kombinationen: 105
#
#    order  part  bend  weld  paint  deadline
# 0      0     0     8     9     36        54
# 1      1     0     4    18      0        24

# %% [markdown]
# ## Parameter

# %%
# for DWave
numr = 10  # Number of samples / quantum computations
#chainStrength is defined als max absolute value in QUBO (see find_chstr(QUBO))


#for QUBO
alpha = 2
beta = 1.5
gamma = 2
delta = 0.035

# %% [markdown]
# ## QUBO

# %%
QUBO = get_QUBO(jobs, operations, alpha, beta, gamma, delta, bend_length, weld_length, paint_length, bend, weld, paint)

# %%
get_qubo_heatmap(QUBO, operations, "QUBO_100")

# %%
qubo_dictionary = qubo_to_dictionary_ohne_null(QUBO, operations)

# %% [markdown]
# ## QBSolve + Neal

# %% [raw]
# for i in range(10, 26, 5):
#     print(i)
#     sampleset_QBSolveHybrid_neal = on_QBsolv_Hybrid(False, QUBO, i, "QBSolve_Hybrid_neal_100")
#     analyse_HS(i, sampleset_QBSolveHybrid_neal, "QB_neal_100.txt" )

# %% [markdown]
# ## QBSolve + Advantage

# %%
sampler = EmbeddingComposite(DWaveSampler(solver={'topology__type': 'pegasus'}))

# %%
subqubo_size = 5

# %%
#response = QBSolv().sample_qubo(QUBO, solver=sampler, solver_limit=subqubo_size, label="QBSolve_Hybrid_adv_100")

# %%
#subQUBO sizes 5 10 15 20 25 30 35 40 45 50 55 60
#   HIER IN SER TABELLE IST RUN == SUB QUBO SIZE

#analyse_HS(subqubo_size, response, "QB_adv_100.txt" )

# %%
# Results already run

# %%
subqubo_size = 10

# %%
#response = QBSolv().sample_qubo(QUBO, solver=sampler, solver_limit=subqubo_size, label="QBSolve_Hybrid_adv_100")

# %%
#subQUBO sizes 5 10 15 20 25 30 35 40 45 50 55 60
#   HIER IN SER TABELLE IST RUN == SUB QUBO SIZE

#analyse_HS(subqubo_size, response, "QB_adv_100.txt" )

# %%
# Results already run

# %%
subqubo_size = 15

# %%
response = QBSolv().sample_qubo(QUBO, solver=sampler, solver_limit=subqubo_size, label="QBSolve_Hybrid_adv_100")

# %%
#subQUBO sizes 5 10 15 20 25 30 35 40 45 50 55 60
#   HIER IN SER TABELLE IST RUN == SUB QUBO SIZE

analyse_HS(subqubo_size, response, "QB_adv_100.txt" )
# Out:
# +-----+------------+-------+-------------------+
# | Run | Min_Energy |  GS % |       BKS %       |
# +-----+------------+-------+-------------------+
# |  15 |  [-10.0]   | 100.0 | 94.44444444444444 |
# +-----+------------+-------+-------------------+

# %%
subqubo_size = 20

# %%
response = QBSolv().sample_qubo(QUBO, solver=sampler, solver_limit=subqubo_size, label="QBSolve_Hybrid_adv_100")

# %%
#subQUBO sizes 5 10 15 20 25 30 35 40 45 50 55 60
#   HIER IN SER TABELLE IST RUN == SUB QUBO SIZE

analyse_HS(subqubo_size, response, "QB_adv_100.txt" )
# Out:
# +-----+------------+-------+------------------+
# | Run | Min_Energy |  GS % |      BKS %       |
# +-----+------------+-------+------------------+
# |  20 |  [-10.0]   | 100.0 | 70.6896551724138 |
# +-----+------------+-------+------------------+

# %%
subqubo_size = 25

# %%
response = QBSolv().sample_qubo(QUBO, solver=sampler, solver_limit=subqubo_size, label="QBSolve_Hybrid_adv_100")

# %%
#subQUBO sizes 5 10 15 20 25 30 35 40 45 50 55 60
#   HIER IN SER TABELLE IST RUN == SUB QUBO SIZE

analyse_HS(subqubo_size, response, "QB_adv_100.txt" )
# Out:
# +-----+------------+-------+------------------+
# | Run | Min_Energy |  GS % |      BKS %       |
# +-----+------------+-------+------------------+
# |  25 |  [-10.0]   | 100.0 | 73.6842105263158 |
# +-----+------------+-------+------------------+

# %%
subqubo_size = 30

# %%
response = QBSolv().sample_qubo(QUBO, solver=sampler, solver_limit=subqubo_size, label="QBSolve_Hybrid_adv_100")

# %%
#subQUBO sizes 5 10 15 20 25 30 35 40 45 50 55 60
#   HIER IN SER TABELLE IST RUN == SUB QUBO SIZE

analyse_HS(subqubo_size, response, "QB_adv_100.txt" )
# Out:
# +-----+------------+-------+-------------------+
# | Run | Min_Energy |  GS % |       BKS %       |
# +-----+------------+-------+-------------------+
# |  30 |  [-10.0]   | 100.0 | 54.54545454545455 |
# +-----+------------+-------+-------------------+

# %%
subqubo_size = 35

# %%
response = QBSolv().sample_qubo(QUBO, solver=sampler, solver_limit=subqubo_size, label="QBSolve_Hybrid_adv_100")

# %%
#subQUBO sizes 5 10 15 20 25 30 35 40 45 50 55 60
#   HIER IN SER TABELLE IST RUN == SUB QUBO SIZE

analyse_HS(subqubo_size, response, "QB_adv_100.txt" )
# Out:
# +-----+------------+-------+-------+
# | Run | Min_Energy |  GS % | BKS % |
# +-----+------------+-------+-------+
# |  35 |  [-10.0]   | 100.0 |  37.5 |
# +-----+------------+-------+-------+

# %%
subqubo_size = 40

# %%
response = QBSolv().sample_qubo(QUBO, solver=sampler, solver_limit=subqubo_size, label="QBSolve_Hybrid_adv_100")
# Out:
# ---------------------------------------------------------------------------
# SolverFailureError                        Traceback (most recent call last)
# python/dwave_qbsolv/qbsolv_binding.pyx in dwave_qbsolv.qbsolv_binding.run_qbsolv.dimod_callback()
#
# /opt/miniconda3/lib/python3.8/site-packages/dimod/sampleset.py in samples(self, n, sorted_by)
#     980             samples = self.record.sample
#     981         else:
# --> 982             order = np.argsort(self.record[sorted_by])
#     983             samples = self.record.sample[order]
#     984
#
# /opt/miniconda3/lib/python3.8/site-packages/dimod/sampleset.py in record(self)
#     871
#     872         """
# --> 873         self.resolve()
#     874         return self._record
#     875
#
# /opt/miniconda3/lib/python3.8/site-packages/dimod/sampleset.py in resolve(self)
#    1206         # if it doesn't have the attribute then it is already resolved
#    1207         if hasattr(self, '_future'):
# ...

# %%
#subQUBO sizes 5 10 15 20 25 30 35 40 45 50 55 60
#   HIER IN SER TABELLE IST RUN == SUB QUBO SIZE

analyse_HS(subqubo_size, response, "QB_adv_100.txt" )

# %%
subqubo_size = 45

# %%
#response = QBSolv().sample_qubo(QUBO, solver=sampler, solver_limit=subqubo_size, label="QBSolve_Hybrid_adv_100")

# %%
#subQUBO sizes 5 10 15 20 25 30 35 40 45 50 55 60
#   HIER IN SER TABELLE IST RUN == SUB QUBO SIZE

#analyse_HS(subqubo_size, response, "QB_adv_100.txt" )

# %%
subqubo_size = 50

# %%
response = QBSolv().sample_qubo(QUBO, solver=sampler, solver_limit=subqubo_size, label="QBSolve_Hybrid_adv_100")
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /opt/miniconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# /opt/miniconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...

# %%
#subQUBO sizes 5 10 15 20 25 30 35 40 45 50 55 60
#   HIER IN SER TABELLE IST RUN == SUB QUBO SIZE

analyse_HS(subqubo_size, response, "QB_adv_100.txt" )

# %%
subqubo_size = 55

# %%
#response = QBSolv().sample_qubo(QUBO, solver=sampler, solver_limit=subqubo_size, label="QBSolve_Hybrid_adv_100")

# %%
#subQUBO sizes 5 10 15 20 25 30 35 40 45 50 55 60
#   HIER IN SER TABELLE IST RUN == SUB QUBO SIZE

#analyse_HS(subqubo_size, response, "QB_adv_100.txt" )

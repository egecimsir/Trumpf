# %%
from qubo_util import *
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv (r'data.csv', sep = ';')

# %%
df = df.drop(columns=['Average Energy', 'Standard Deviation', 'Lowest Energy'])

# %%
df
# Out:
#     Complexity               QPU        Label  Best Known Solutions (%)  \
# 0        Job10  D-Wave Advantage  embedding1A                      16.8
# 1        Job10  D-Wave Advantage  embedding1B                      18.4
# 2        Job10  D-Wave Advantage  embedding2A                      14.6
# 3        Job10  D-Wave Advantage  embedding2B                      13.4
# 4        Job10  D-Wave Advantage  embedding3A                      20.0
# ..         ...               ...          ...                       ...
# 151     Job500       Fujitsu DAU         6.00                       1.0
# 152     Job500       Fujitsu DAU         7.00                       1.0
# 153     Job500       Fujitsu DAU         8.00                       1.0
# 154     Job500       Fujitsu DAU         9.00                       1.0
# 155     Job500       Fujitsu DAU        10.00                       1.0
#
#      Good Known Solutions (%)
# 0                        42.0
# 1                        45.6
# ...

# %%
std = df.groupby(["Complexity", "QPU"], sort=False).std(ddof=0).reset_index()

# %%
std
# Out:
#   Complexity               QPU  Best Known Solutions (%)  \
# 0      Job10  D-Wave Advantage                  5.599103
# 1      Job20  D-Wave Advantage                  0.561783
# 2      Job50  D-Wave Advantage                  0.107238
# 3     Job100  D-Wave Advantage                  0.040786
# 4      Job10       Fujitsu DAU                  0.618241
# 5      Job20       Fujitsu DAU                  4.177187
# 6      Job50       Fujitsu DAU                  1.496663
# 7     Job100       Fujitsu DAU                  0.640312
# 8     Job500       Fujitsu DAU                  0.000000
#
#    Good Known Solutions (%)
# 0                 13.384891
# 1                  7.308625
# 2                  1.089036
# 3                  0.194051
# 4                  0.000000
# 5                  0.000000
# 6                  3.476908
# 7                  1.846619
# 8                  2.107131

# %%
sns.set_theme(style="whitegrid")

# "Melt" the dataset to "long-form" or "tidy" representation
plot = pd.melt(df, "QPU", var_name="Best Known Solutions (%)")

# Initialize the figure
f, ax = plt.subplots(figsize=(8,6))
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="Complexity", y="Best Known Solutions (%)", hue="QPU",
              data=df, 
              dodge=True, 
              alpha=.35, 
              zorder=1
             )

# Show the conditional means
sns.pointplot(x="Complexity", y="Best Known Solutions (%)", hue="QPU",
              data=df, 
              dodge=.55, 
              #join=False, 
              linestyles=["--","--"],
              #palette="dark",
              #markers="d", 
              scale=0.45, 
              ci=None
             )

# Show the conditional means
sns.pointplot(x="Complexity", y="Best Known Solutions (%)", hue="QPU",
              data=df, 
              dodge=.55, 
              join=False, 
              #palette="dark",
              markers="d", 
              scale=1.1, 
              ci=None
             )

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[4:], labels[4:], title="QPU",
          handletextpad=0, columnspacing=1,
          loc="upper right", ncol=3, frameon=True)

plt.savefig('Best Known Solutions by Complexity.pdf')

# %%
sns.set_theme(style="whitegrid")

# "Melt" the dataset to "long-form" or "tidy" representation
plot = pd.melt(df, "QPU", var_name="Good Known Solutions (%)")

# Initialize the figure
f, ax = plt.subplots(figsize=(8,6))
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="Complexity", y="Good Known Solutions (%)", hue="QPU",
              data=df, 
              dodge=True, 
              alpha=.35, 
              zorder=1
             )

# Show the conditional means
sns.pointplot(x="Complexity", y="Good Known Solutions (%)", hue="QPU",
              data=df, 
              dodge=.55, 
              #join=False, 
              linestyles=["--","--"],
              #palette="dark",
              #markers="d", 
              scale=0.45, 
              ci=None
             )

# Show the conditional means
sns.pointplot(x="Complexity", y="Good Known Solutions (%)", hue="QPU",
              data=df, 
              dodge=.55, 
              join=False, 
              #palette="dark",
              markers="d", 
              scale=1.1, 
              ci=None
             )

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[4:], labels[4:], title="QPU",
          handletextpad=0, columnspacing=1,
          loc="upper right", ncol=3, frameon=True)

plt.savefig('Good Known Solutions by Complexity.pdf')
